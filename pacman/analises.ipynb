# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot
import pandas as pd

# %%
game = "CartPole-v0"
train_loss = pd.read_csv(game+"/train_loss.csv",delimiter=",",header=None)
train_scores = pd.read_csv(game+"/train_scores.csv",delimiter=",",header=None)
test_scores = pd.read_csv(game+"/test_scores.csv",delimiter=",",header=None)
size = (4,4)

# %%
train_loss.plot(figsize=size)
train_loss.hist(figsize=size,range=(train_loss.min()[0],train_loss.max()[0]))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fa3a20d5470>]], dtype=object)

# %%
train_scores.plot(figsize=size)
train_scores.hist(figsize=size,range=(train_scores.min()[0],train_scores.max()[0]))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fa3a2c96048>]], dtype=object)

# %%
test_scores.plot(figsize=size)
test_scores.hist(figsize=size,range=(test_scores.min()[0],test_scores.max()[0]))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fa3a2bca438>]], dtype=object)
